# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import assignment2_helper as helper

# Look pretty...
matplotlib.style.use('ggplot')
# %matplotlib inline

# Do * NOT * alter this line, until instructed!
scaleFeatures = True

# %%
# TODO: Load up the dataset and remove any and all
# Rows that have a nan. You should be a pro at this
# by now ;-)
#
# .. your code here ..
datafile = './Datasets/kidney_disease.csv'
df = pd.read_csv(datafile, header=0)
df
# Out:
#       id   age     bp     sg   al   su       rbc        pc         pcc  \
# 0      0  48.0   80.0  1.020  1.0  0.0       NaN    normal  notpresent
# 1      1   7.0   50.0  1.020  4.0  0.0       NaN    normal  notpresent
# 2      2  62.0   80.0  1.010  2.0  3.0    normal    normal  notpresent
# 3      3  48.0   70.0  1.005  4.0  0.0    normal  abnormal     present
# 4      4  51.0   80.0  1.010  2.0  0.0    normal    normal  notpresent
# 5      5  60.0   90.0  1.015  3.0  0.0       NaN       NaN  notpresent
# 6      6  68.0   70.0  1.010  0.0  0.0       NaN    normal  notpresent
# 7      7  24.0    NaN  1.015  2.0  4.0    normal  abnormal  notpresent
# 8      8  52.0  100.0  1.015  3.0  0.0    normal  abnormal     present
# 9      9  53.0   90.0  1.020  2.0  0.0  abnormal  abnormal     present
# 10    10  50.0   60.0  1.010  2.0  4.0       NaN  abnormal     present
# 11    11  63.0   70.0  1.010  3.0  0.0  abnormal  abnormal     present
# 12    12  68.0   70.0  1.015  3.0  1.0       NaN    normal     present
# 13    13  68.0   70.0    NaN  NaN  NaN       NaN       NaN  notpresent
# 14    14  68.0   80.0  1.010  3.0  2.0    normal  abnormal     present
# 15    15  40.0   80.0  1.015  3.0  0.0       NaN    normal  notpresent
# 16    16  47.0   70.0  1.015  2.0  0.0       NaN    normal  notpresent
# 17    17  47.0   80.0    NaN  NaN  NaN       NaN       NaN  notpresent
# 18    18  60.0  100.0  1.025  0.0  3.0       NaN    normal  notpresent
# 19    19  62.0   60.0  1.015  1.0  0.0       NaN  abnormal     present
# 20    20  61.0   80.0  1.015  2.0  0.0  abnormal  abnormal  notpresent
# 21    21  60.0   90.0    NaN  NaN  NaN       NaN       NaN  notpresent
# 22    22  48.0   80.0  1.025  4.0  0.0    normal  abnormal  notpresent
# 23    23  21.0   70.0  1.010  0.0  0.0       NaN    normal  notpresent
# 24    24  42.0  100.0  1.015  4.0  0.0    normal  abnormal  notpresent
# 25    25  61.0   60.0  1.025  0.0  0.0       NaN    normal  notpresent
# 26    26  75.0   80.0  1.015  0.0  0.0       NaN    normal  notpresent
# 27    27  69.0   70.0  1.010  3.0  4.0    normal  abnormal  notpresent
# 28    28  75.0   70.0    NaN  1.0  3.0       NaN       NaN  notpresent
# 29    29  68.0   70.0  1.005  1.0  0.0  abnormal  abnormal     present
# ..   ...   ...    ...    ...  ...  ...       ...       ...         ...
# 370  370  69.0   70.0  1.020  0.0  0.0    normal    normal  notpresent
# 371  371  28.0   60.0  1.025  0.0  0.0    normal    normal  notpresent
# 372  372  72.0   60.0  1.020  0.0  0.0    normal    normal  notpresent
# 373  373  61.0   70.0  1.025  0.0  0.0    normal    normal  notpresent
# 374  374  79.0   80.0  1.025  0.0  0.0    normal    normal  notpresent
# 375  375  70.0   80.0  1.020  0.0  0.0    normal    normal  notpresent
# 376  376  58.0   70.0  1.025  0.0  0.0    normal    normal  notpresent
# 377  377  64.0   70.0  1.020  0.0  0.0    normal    normal  notpresent
# 378  378  71.0   60.0  1.025  0.0  0.0    normal    normal  notpresent
# 379  379  62.0   80.0  1.025  0.0  0.0    normal    normal  notpresent
# 380  380  59.0   60.0  1.020  0.0  0.0    normal    normal  notpresent
# 381  381  71.0   70.0  1.025  0.0  0.0       NaN       NaN  notpresent
# 382  382  48.0   80.0  1.025  0.0  0.0    normal    normal  notpresent
# 383  383  80.0   80.0  1.025  0.0  0.0    normal    normal  notpresent
# 384  384  57.0   60.0  1.020  0.0  0.0    normal    normal  notpresent
# 385  385  63.0   70.0  1.020  0.0  0.0    normal    normal  notpresent
# 386  386  46.0   70.0  1.025  0.0  0.0    normal    normal  notpresent
# 387  387  15.0   80.0  1.025  0.0  0.0    normal    normal  notpresent
# 388  388  51.0   80.0  1.020  0.0  0.0    normal    normal  notpresent
# 389  389  41.0   80.0  1.025  0.0  0.0    normal    normal  notpresent
# 390  390  52.0   80.0  1.025  0.0  0.0    normal    normal  notpresent
# 391  391  36.0   80.0  1.025  0.0  0.0    normal    normal  notpresent
# 392  392  57.0   80.0  1.020  0.0  0.0    normal    normal  notpresent
# 393  393  43.0   60.0  1.025  0.0  0.0    normal    normal  notpresent
# 394  394  50.0   80.0  1.020  0.0  0.0    normal    normal  notpresent
# 395  395  55.0   80.0  1.020  0.0  0.0    normal    normal  notpresent
# 396  396  42.0   70.0  1.025  0.0  0.0    normal    normal  notpresent
# 397  397  12.0   80.0  1.020  0.0  0.0    normal    normal  notpresent
# 398  398  17.0   60.0  1.025  0.0  0.0    normal    normal  notpresent
# 399  399  58.0   80.0  1.025  0.0  0.0    normal    normal  notpresent
#
#              ba      ...        pcv     wc   rc  htn   dm  cad appet   pe  \
# 0    notpresent      ...         44   7800  5.2  yes  yes   no  good   no
# 1    notpresent      ...         38   6000  NaN   no   no   no  good   no
# 2    notpresent      ...         31   7500  NaN   no  yes   no  poor   no
# 3    notpresent      ...         32   6700  3.9  yes   no   no  poor  yes
# 4    notpresent      ...         35   7300  4.6   no   no   no  good   no
# 5    notpresent      ...         39   7800  4.4  yes  yes   no  good  yes
# 6    notpresent      ...         36    NaN  NaN   no   no   no  good   no
# 7    notpresent      ...         44   6900    5   no  yes   no  good  yes
# 8    notpresent      ...         33   9600  4.0  yes  yes   no  good   no
# 9    notpresent      ...         29  12100  3.7  yes  yes   no  poor   no
# 10   notpresent      ...         28    NaN  NaN  yes  yes   no  good   no
# 11   notpresent      ...         32   4500  3.8  yes  yes   no  poor  yes
# 12   notpresent      ...         28  12200  3.4  yes  yes  yes  poor  yes
# 13   notpresent      ...        NaN    NaN  NaN  yes  yes  yes  poor  yes
# 14      present      ...         16  11000  2.6  yes  yes  yes  poor  yes
# 15   notpresent      ...         24   3800  2.8  yes   no   no  good   no
# 16   notpresent      ...        NaN    NaN  NaN   no   no   no  good   no
# 17   notpresent      ...        NaN    NaN  NaN  yes   no   no  poor   no
# 18   notpresent      ...         37  11400  4.3  yes  yes  yes  good   no
# 19   notpresent      ...         30   5300  3.7  yes   no  yes  good   no
# 20   notpresent      ...         24   9200  3.2  yes  yes  yes  poor  yes
# 21   notpresent      ...         32   6200  3.6  yes  yes  yes  good   no
# 22   notpresent      ...         32   6900  3.4  yes   no   no  good   no
# 23   notpresent      ...        NaN    NaN  NaN   no   no   no  poor   no
# 24      present      ...         39   8300  4.6  yes   no   no  poor   no
# 25   notpresent      ...         29   8400  3.7  yes  yes   no  good   no
# 26   notpresent      ...         35  10300    4  yes  yes   no  poor   no
# 27   notpresent      ...         37   9600  4.1  yes  yes  yes  good  yes
# 28   notpresent      ...        NaN    NaN  NaN   no  yes   no  good   no
# 29   notpresent      ...         38    NaN  NaN   no   no  yes  good   no
# ..          ...      ...        ...    ...  ...  ...  ...  ...   ...  ...
# 370  notpresent      ...         50   9300  5.4   no   no   no  good   no
# 371  notpresent      ...         51   6500  5.0   no   no   no  good   no
# 372  notpresent      ...         52  10500  5.5   no   no   no  good   no
# 373  notpresent      ...         47   9200  4.9   no   no   no  good   no
# 374  notpresent      ...         40   8000  6.4   no   no   no  good   no
# 375  notpresent      ...         48   9700  5.6   no   no   no  good   no
# 376  notpresent      ...         53   9100  5.2   no   no   no  good   no
# 377  notpresent      ...         49   6400  4.8   no   no   no  good   no
# 378  notpresent      ...         42   7700  5.5   no   no   no  good   no
# 379  notpresent      ...         50   5400  5.7   no   no   no  good   no
# 380  notpresent      ...         54   6500  4.9   no   no   no  good   no
# 381  notpresent      ...         40   5800  5.9   no   no   no  good   no
# 382  notpresent      ...         51   6000  6.5   no   no   no  good   no
# 383  notpresent      ...         49   5100  5.0   no   no   no  good   no
# 384  notpresent      ...         42  11000  4.5   no   no   no  good   no
# 385  notpresent      ...         52   8000  5.1   no   no   no  good   no
# 386  notpresent      ...         43   5700  6.5   no   no   no  good   no
# 387  notpresent      ...         50   6200  5.2   no   no   no  good   no
# 388  notpresent      ...         46   9500  6.4   no   no   no  good   no
# 389  notpresent      ...         52   7200  5.8   no   no   no  good   no
# 390  notpresent      ...         52   6300  5.3   no   no   no  good   no
# 391  notpresent      ...         44   5800  6.3   no   no   no  good   no
# 392  notpresent      ...         46   6600  5.5   no   no   no  good   no
# 393  notpresent      ...         54   7400  5.4   no   no   no  good   no
# 394  notpresent      ...         45   9500  4.6   no   no   no  good   no
# 395  notpresent      ...         47   6700  4.9   no   no   no  good   no
# 396  notpresent      ...         54   7800  6.2   no   no   no  good   no
# 397  notpresent      ...         49   6600  5.4   no   no   no  good   no
# 398  notpresent      ...         51   7200  5.9   no   no   no  good   no
# 399  notpresent      ...         53   6800  6.1   no   no   no  good   no
#
#      ane classification
# 0     no            ckd
# 1     no            ckd
# 2    yes            ckd
# 3    yes            ckd
# 4     no            ckd
# 5     no            ckd
# 6     no            ckd
# 7     no            ckd
# 8    yes            ckd
# 9    yes            ckd
# 10   yes            ckd
# 11    no            ckd
# 12    no            ckd
# 13    no            ckd
# 14    no            ckd
# 15   yes            ckd
# 16    no            ckd
# 17    no            ckd
# 18    no            ckd
# 19    no            ckd
# 20   yes            ckd
# 21    no            ckd
# 22   yes            ckd
# 23   yes            ckd
# 24    no            ckd
# 25   yes            ckd
# 26    no            ckd
# 27    no            ckd
# 28    no            ckd
# 29    no            ckd
# ..   ...            ...
# 370   no         notckd
# 371   no         notckd
# 372   no         notckd
# 373   no         notckd
# 374   no         notckd
# 375   no         notckd
# 376   no         notckd
# 377   no         notckd
# 378   no         notckd
# 379   no         notckd
# 380   no         notckd
# 381   no         notckd
# 382   no         notckd
# 383   no         notckd
# 384   no         notckd
# 385   no         notckd
# 386   no         notckd
# 387   no         notckd
# 388   no         notckd
# 389   no         notckd
# 390   no         notckd
# 391   no         notckd
# 392   no         notckd
# 393   no         notckd
# 394   no         notckd
# 395   no         notckd
# 396   no         notckd
# 397   no         notckd
# 398   no         notckd
# 399   no         notckd
#
# [400 rows x 26 columns]

# %%
df = df.drop(labels=['id', 'rbc', 'pc', 'pcc', 'ba', 'htn', 'dm', 'cad', 'appet', 'pe', 'ane'], axis=1)
df = df.dropna(axis=0)
df
# Out:
#       age     bp     sg   al   su    bgr     bu    sc    sod  pot  hemo pcv  \
# 3    48.0   70.0  1.005  4.0  0.0  117.0   56.0   3.8  111.0  2.5  11.2  32
# 5    60.0   90.0  1.015  3.0  0.0   74.0   25.0   1.1  142.0  3.2  12.2  39
# 9    53.0   90.0  1.020  2.0  0.0   70.0  107.0   7.2  114.0  3.7   9.5  29
# 11   63.0   70.0  1.010  3.0  0.0  380.0   60.0   2.7  131.0  4.2  10.8  32
# 12   68.0   70.0  1.015  3.0  1.0  208.0   72.0   2.1  138.0  5.8   9.7  28
# 14   68.0   80.0  1.010  3.0  2.0  157.0   90.0   4.1  130.0  6.4   5.6  16
# 15   40.0   80.0  1.015  3.0  0.0   76.0  162.0   9.6  141.0  4.9   7.6  24
# 18   60.0  100.0  1.025  0.0  3.0  263.0   27.0   1.3  135.0  4.3  12.7  37
# 20   61.0   80.0  1.015  2.0  0.0  173.0  148.0   3.9  135.0  5.2   7.7  24
# 22   48.0   80.0  1.025  4.0  0.0   95.0  163.0   7.7  136.0  3.8   9.8  32
# 25   61.0   60.0  1.025  0.0  0.0  108.0   75.0   1.9  141.0  5.2   9.9  29
# 26   75.0   80.0  1.015  0.0  0.0  156.0   45.0   2.4  140.0  3.4  11.6  35
# 27   69.0   70.0  1.010  3.0  4.0  264.0   87.0   2.7  130.0  4.0  12.5  37
# 31   73.0   90.0  1.015  3.0  0.0  107.0   33.0   1.5  141.0  4.6  10.1  30
# 32   61.0   90.0  1.010  1.0  1.0  159.0   39.0   1.5  133.0  4.9  11.3  34
# 39   82.0   80.0  1.010  2.0  2.0  140.0   70.0   3.4  136.0  4.2  13.0  40
# 42   47.0  100.0  1.010  0.0  0.0  204.0   29.0   1.0  139.0  4.2   9.7  33
# 43   35.0   80.0  1.010  1.0  0.0   79.0  202.0  10.8  134.0  3.4   7.9  24
# 46   48.0   70.0  1.015  0.0  0.0  124.0   24.0   1.2  142.0  4.2  12.4  37
# 48   73.0   70.0  1.005  0.0  0.0   70.0   32.0   0.9  125.0  4.0  10.0  29
# 58   73.0   80.0  1.020  2.0  0.0  253.0  142.0   4.6  138.0  5.8  10.5  33
# 62   15.0   60.0  1.020  3.0  0.0   86.0   15.0   0.6  138.0  4.0  11.0  33
# 70   61.0   80.0  1.015  0.0  4.0  360.0   19.0   0.7  137.0  4.4  15.2  44
# 71   46.0   60.0  1.010  1.0  0.0  163.0   92.0   3.3  141.0  4.0   9.8  28
# 74   56.0   90.0  1.015  2.0  0.0  129.0  107.0   6.7  131.0  4.8   9.1  29
# 76   48.0   80.0  1.005  4.0  0.0  133.0  139.0   8.5  132.0  5.5  10.3  36
# 77   67.0   70.0  1.010  1.0  0.0  102.0   48.0   3.2  137.0  5.0  11.9  34
# 80   74.0   80.0  1.010  0.0  0.0  132.0   98.0   2.8  133.0  5.0  10.8  31
# 84   59.0   70.0  1.010  3.0  0.0   76.0  186.0  15.0  135.0  7.6   7.1  22
# 90   63.0  100.0  1.010  2.0  2.0  280.0   35.0   3.2  143.0  3.5  13.0  40
# ..    ...    ...    ...  ...  ...    ...    ...   ...    ...  ...   ...  ..
# 369  75.0   70.0  1.020  0.0  0.0  107.0   48.0   0.8  144.0  3.5  13.6  46
# 370  69.0   70.0  1.020  0.0  0.0   83.0   42.0   1.2  139.0  3.7  16.2  50
# 371  28.0   60.0  1.025  0.0  0.0   79.0   50.0   0.5  145.0  5.0  17.6  51
# 372  72.0   60.0  1.020  0.0  0.0  109.0   26.0   0.9  150.0  4.9  15.0  52
# 373  61.0   70.0  1.025  0.0  0.0  133.0   38.0   1.0  142.0  3.6  13.7  47
# 374  79.0   80.0  1.025  0.0  0.0  111.0   44.0   1.2  146.0  3.6  16.3  40
# 375  70.0   80.0  1.020  0.0  0.0   74.0   41.0   0.5  143.0  4.5  15.1  48
# 376  58.0   70.0  1.025  0.0  0.0   88.0   16.0   1.1  147.0  3.5  16.4  53
# 377  64.0   70.0  1.020  0.0  0.0   97.0   27.0   0.7  145.0  4.8  13.8  49
# 379  62.0   80.0  1.025  0.0  0.0   78.0   45.0   0.6  138.0  3.5  16.1  50
# 380  59.0   60.0  1.020  0.0  0.0  113.0   23.0   1.1  139.0  3.5  15.3  54
# 381  71.0   70.0  1.025  0.0  0.0   79.0   47.0   0.5  142.0  4.8  16.6  40
# 382  48.0   80.0  1.025  0.0  0.0   75.0   22.0   0.8  137.0  5.0  16.8  51
# 383  80.0   80.0  1.025  0.0  0.0  119.0   46.0   0.7  141.0  4.9  13.9  49
# 384  57.0   60.0  1.020  0.0  0.0  132.0   18.0   1.1  150.0  4.7  15.4  42
# 385  63.0   70.0  1.020  0.0  0.0  113.0   25.0   0.6  146.0  4.9  16.5  52
# 386  46.0   70.0  1.025  0.0  0.0  100.0   47.0   0.5  142.0  3.5  16.4  43
# 387  15.0   80.0  1.025  0.0  0.0   93.0   17.0   0.9  136.0  3.9  16.7  50
# 388  51.0   80.0  1.020  0.0  0.0   94.0   15.0   1.2  144.0  3.7  15.5  46
# 389  41.0   80.0  1.025  0.0  0.0  112.0   48.0   0.7  140.0  5.0  17.0  52
# 390  52.0   80.0  1.025  0.0  0.0   99.0   25.0   0.8  135.0  3.7  15.0  52
# 391  36.0   80.0  1.025  0.0  0.0   85.0   16.0   1.1  142.0  4.1  15.6  44
# 392  57.0   80.0  1.020  0.0  0.0  133.0   48.0   1.2  147.0  4.3  14.8  46
# 393  43.0   60.0  1.025  0.0  0.0  117.0   45.0   0.7  141.0  4.4  13.0  54
# 394  50.0   80.0  1.020  0.0  0.0  137.0   46.0   0.8  139.0  5.0  14.1  45
# 395  55.0   80.0  1.020  0.0  0.0  140.0   49.0   0.5  150.0  4.9  15.7  47
# 396  42.0   70.0  1.025  0.0  0.0   75.0   31.0   1.2  141.0  3.5  16.5  54
# 397  12.0   80.0  1.020  0.0  0.0  100.0   26.0   0.6  137.0  4.4  15.8  49
# 398  17.0   60.0  1.025  0.0  0.0  114.0   50.0   1.0  135.0  4.9  14.2  51
# 399  58.0   80.0  1.025  0.0  0.0  131.0   18.0   1.1  141.0  3.5  15.8  53
#
#          wc   rc classification
# 3      6700  3.9            ckd
# 5      7800  4.4            ckd
# 9     12100  3.7            ckd
# 11     4500  3.8            ckd
# 12    12200  3.4            ckd
# 14    11000  2.6            ckd
# 15     3800  2.8            ckd
# 18    11400  4.3            ckd
# 20     9200  3.2            ckd
# 22     6900  3.4            ckd
# 25     8400  3.7            ckd
# 26    10300    4            ckd
# 27     9600  4.1            ckd
# 31     7800    4            ckd
# 32     9600  4.0            ckd
# 39     9800  4.2            ckd
# 42     9200  4.5            ckd
# 43     7900  3.1            ckd
# 46     6400  4.7            ckd
# 48    18900  3.5            ckd
# 58     7200  4.3            ckd
# 62     7700  3.8            ckd
# 70     8300  5.2            ckd
# 71    14600  3.2            ckd
# 74     6400  3.4            ckd
# 76   \t6200    4            ckd
# 77     7100  3.7            ckd
# 80     9400  3.8            ckd
# 84     3800  2.1            ckd
# 90     9800  4.2            ckd
# ..      ...  ...            ...
# 369   10300  4.8         notckd
# 370    9300  5.4         notckd
# 371    6500  5.0         notckd
# 372   10500  5.5         notckd
# 373    9200  4.9         notckd
# 374    8000  6.4         notckd
# 375    9700  5.6         notckd
# 376    9100  5.2         notckd
# 377    6400  4.8         notckd
# 379    5400  5.7         notckd
# 380    6500  4.9         notckd
# 381    5800  5.9         notckd
# 382    6000  6.5         notckd
# 383    5100  5.0         notckd
# 384   11000  4.5         notckd
# 385    8000  5.1         notckd
# 386    5700  6.5         notckd
# 387    6200  5.2         notckd
# 388    9500  6.4         notckd
# 389    7200  5.8         notckd
# 390    6300  5.3         notckd
# 391    5800  6.3         notckd
# 392    6600  5.5         notckd
# 393    7400  5.4         notckd
# 394    9500  4.6         notckd
# 395    6700  4.9         notckd
# 396    7800  6.2         notckd
# 397    6600  5.4         notckd
# 398    7200  5.9         notckd
# 399    6800  6.1         notckd
#
# [203 rows x 15 columns]

# %%
df.dtypes
# Out:
# age               float64
# bp                float64
# sg                float64
# al                float64
# su                float64
# bgr               float64
# bu                float64
# sc                float64
# sod               float64
# pot               float64
# hemo              float64
# pcv                object
# wc                 object
# rc                 object
# classification     object
# dtype: object

# %%
df.wc = pd.to_numeric(df.wc, errors='coerce')
df.rc = pd.to_numeric(df.rc, errors='coerce')
df.pcv = pd.to_numeric(df.pcv, errors='coerce')
df = df.dropna()
df.dtypes
# Out:
# age               float64
# bp                float64
# sg                float64
# al                float64
# su                float64
# bgr               float64
# bu                float64
# sc                float64
# sod               float64
# pot               float64
# hemo              float64
# pcv                 int64
# wc                  int64
# rc                float64
# classification     object
# dtype: object

# %%
df.describe()
# Out:
#               age          bp          sg          al          su         bgr  \
# count  203.000000  203.000000  203.000000  203.000000  203.000000  203.000000
# mean    51.857143   74.926108    1.019039    0.822660    0.359606  138.029557
# std     15.641538   11.534256    0.005645    1.359994    0.971751   75.476369
# min      6.000000   50.000000    1.005000    0.000000    0.000000   70.000000
# 25%     42.000000   70.000000    1.015000    0.000000    0.000000   95.500000
# 50%     55.000000   80.000000    1.020000    0.000000    0.000000  117.000000
# 75%     63.000000   80.000000    1.025000    1.500000    0.000000  133.500000
# max     90.000000  110.000000    1.025000    4.000000    5.000000  490.000000
#
#                bu          sc         sod         pot        hemo         pcv  \
# count  203.000000  203.000000  203.000000  203.000000  203.000000  203.000000
# mean    53.256158    2.251232  138.709360    4.568966   13.344335   40.669951
# std     45.771964    2.944274    6.908114    3.085574    2.833150    8.936211
# min     10.000000    0.400000  111.000000    2.500000    3.100000    9.000000
# 25%     26.000000    0.800000  135.000000    3.750000   11.300000   34.000000
# 50%     40.000000    1.100000  139.000000    4.500000   13.900000   42.000000
# 75%     51.500000    2.200000  142.500000    4.900000   15.500000   48.000000
# max    309.000000   15.200000  150.000000   47.000000   17.800000   54.000000
#
#                  wc          rc
# count    203.000000  203.000000
# mean    8592.610837    4.788670
# std     2927.252383    1.001345
# min     3800.000000    2.100000
# 25%     6700.000000    4.050000
# 50%     8100.000000    4.800000
# 75%     9800.000000    5.500000
# max    26400.000000    8.000000

# %%
# Create some color coded labels; the actual label feature
# will be removed prior to executing PCA, since it's unsupervised.
# You're only labeling by color so you can see the effects of PCA
labels = ['red' if i=='ckd' else 'green' for i in df.classification]
df = df.drop(labels=['classification'], axis=1)

# %%
# TODO: Print out and check your dataframe's dtypes. You'll probably
# want to call 'exit()' after you print it out so you can stop the
# program's execution.
#
# You can either take a look at the dataset webpage in the attribute info
# section: https://archive.ics.uci.edu/ml/datasets/Chronic_Kidney_Disease
# or you can actually peek through the dataframe by printing a few rows.
# What kind of data type should these three columns be? If Pandas didn't
# properly detect and convert them to that data type for you, then use
# an appropriate command to coerce these features into the right type.
#
# .. your code here ..
df.dtypes
# Out:
# age     float64
# bp      float64
# sg      float64
# al      float64
# su      float64
# bgr     float64
# bu      float64
# sc      float64
# sod     float64
# pot     float64
# hemo    float64
# pcv       int64
# wc        int64
# rc      float64
# dtype: object

# %%
# TODO: PCA Operates based on variance. The variable with the greatest
# variance will dominate. Go ahead and peek into your data using a
# command that will check the variance of every feature in your dataset.
# Print out the results. Also print out the results of running .describe
# on your dataset.
#
# Hint: If you don't see all three variables: 'bgr','wc' and 'rc', then
# you probably didn't complete the previous step properly.
#
# .. your code here ..
print df.var(axis=0)
df.describe()
# Out:
# age     2.446577e+02
# bp      1.330391e+02
# sg      3.186973e-05
# al      1.849583e+00
# su      9.443008e-01
# bgr     5.696682e+03
# bu      2.095073e+03
# sc      8.668748e+00
# sod     4.772204e+01
# pot     9.520765e+00
# hemo    8.026738e+00
# pcv     7.985587e+01
# wc      8.568807e+06
# rc      1.002693e+00
# dtype: float64
#               age          bp          sg          al          su         bgr  \
# count  203.000000  203.000000  203.000000  203.000000  203.000000  203.000000
# mean    51.857143   74.926108    1.019039    0.822660    0.359606  138.029557
# std     15.641538   11.534256    0.005645    1.359994    0.971751   75.476369
# min      6.000000   50.000000    1.005000    0.000000    0.000000   70.000000
# 25%     42.000000   70.000000    1.015000    0.000000    0.000000   95.500000
# 50%     55.000000   80.000000    1.020000    0.000000    0.000000  117.000000
# 75%     63.000000   80.000000    1.025000    1.500000    0.000000  133.500000
# max     90.000000  110.000000    1.025000    4.000000    5.000000  490.000000
#
#                bu          sc         sod         pot        hemo         pcv  \
# count  203.000000  203.000000  203.000000  203.000000  203.000000  203.000000
# mean    53.256158    2.251232  138.709360    4.568966   13.344335   40.669951
# std     45.771964    2.944274    6.908114    3.085574    2.833150    8.936211
# min     10.000000    0.400000  111.000000    2.500000    3.100000    9.000000
# 25%     26.000000    0.800000  135.000000    3.750000   11.300000   34.000000
# 50%     40.000000    1.100000  139.000000    4.500000   13.900000   42.000000
# 75%     51.500000    2.200000  142.500000    4.900000   15.500000   48.000000
# max    309.000000   15.200000  150.000000   47.000000   17.800000   54.000000
#
#                  wc          rc
# count    203.000000  203.000000
# mean    8592.610837    4.788670
# std     2927.252383    1.001345
# min     3800.000000    2.100000
# 25%     6700.000000    4.050000
# 50%     8100.000000    4.800000
# 75%     9800.000000    5.500000
# max    26400.000000    8.000000

# %%
# TODO: This method assumes your dataframe is called df. If it isn't,
# make the appropriate changes. Don't alter the code in scaleFeatures()
# just yet though!
#
# .. your code adjustment here ..
if scaleFeatures: df = helper.scaleFeatures(df)
# Out:
# New Variances:
# age     1.00495
# bp      1.00495
# sg      1.00495
# al      1.00495
# su      1.00495
# bgr     1.00495
# bu      1.00495
# sc      1.00495
# sod     1.00495
# pot     1.00495
# hemo    1.00495
# pcv     1.00495
# wc      1.00495
# rc      1.00495
# dtype: float64
# New Describe:
#                 age            bp            sg            al            su  \
# count  2.030000e+02  2.030000e+02  2.030000e+02  2.030000e+02  2.030000e+02
# mean   2.048170e-16 -5.939420e-16 -2.481868e-14  6.508204e-16 -6.480859e-16
# std    1.002472e+00  1.002472e+00  1.002472e+00  1.002472e+00  1.002472e+00
# min   -2.939002e+00 -2.166393e+00 -2.493056e+00 -6.063953e-01 -3.709744e-01
# 25%   -6.317481e-01 -4.281409e-01 -7.173002e-01 -6.063953e-01 -3.709744e-01
# 50%    2.014269e-01  4.409851e-01  1.705775e-01 -6.063953e-01 -3.709744e-01
# 75%    7.141500e-01  4.409851e-01  1.058455e+00  4.992776e-01 -3.709744e-01
# max    2.444590e+00  3.048363e+00  1.058455e+00  2.342066e+00  4.787095e+00
#
#                 bgr            bu            sc           sod           pot  \
# count  2.030000e+02  2.030000e+02  2.030000e+02  2.030000e+02  2.030000e+02
# mean   1.689262e-16  2.663441e-16 -5.058898e-16  1.891481e-15  1.391881e-16
# std    1.002472e+00  1.002472e+00  1.002472e+00  1.002472e+00  1.002472e+00
# min   -9.035641e-01 -9.473724e-01 -6.303110e-01 -4.021049e+00 -6.721863e-01
# 25%   -5.648748e-01 -5.969493e-01 -4.941182e-01 -5.382844e-01 -2.660738e-01
# 50%   -2.793132e-01 -2.903290e-01 -3.919736e-01  4.217633e-02 -2.240621e-02
# 75%   -6.016127e-02 -3.846239e-02 -1.744341e-02  5.500794e-01  1.075498e-01
# max    4.674848e+00  5.601160e+00  4.408822e+00  1.638443e+00  1.378542e+01
#
#                hemo           pcv            wc            rc
# count  2.030000e+02  2.030000e+02  2.030000e+02  2.030000e+02
# mean   7.399664e-16  4.561212e-16 -1.629786e-16 -2.625158e-16
# std    1.002472e+00  1.002472e+00  1.002472e+00  1.002472e+00
# min   -3.624821e+00 -3.552763e+00 -1.641286e+00 -2.691695e+00
# 25%   -7.233606e-01 -7.482410e-01 -6.481470e-01 -7.395011e-01
# 50%    1.966146e-01  1.492061e-01 -1.687004e-01  1.134280e-02
# 75%    7.627533e-01  8.222915e-01  4.134847e-01  7.121304e-01
# max    1.576578e+00  1.495377e+00  6.098351e+00  3.214943e+00

# %%
# TODO: Run PCA on your dataset and reduce it to 2 components
# Ensure your PCA instance is saved in a variable called 'pca',
# and that the results of your transformation are saved in 'T'.
#
# .. your code here ..
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
pca.fit(df)
T = pca.transform(df)

# %%
# Plot the transformed data as a scatter plot. Recall that transforming
# the data will result in a NumPy NDArray. You can either use MatPlotLib
# to graph it directly, or you can convert it to DataFrame and have pandas
# do it for you.
#
# Since we've already demonstrated how to plot directly with MatPlotLib in
# Module4/assignment1.py, this time we'll convert to a Pandas Dataframe.
#
# Since we transformed via PCA, we no longer have column names. We know we
# are in P.C. space, so we'll just define the coordinates accordingly:
ax = helper.drawVectors(T, pca.components_, df.columns.values, plt, scaleFeatures)
T = pd.DataFrame(T)
T.columns = ['component1', 'component2']
T.plot.scatter(x='component1', y='component2', marker='o', c=labels, alpha=0.75, ax=ax)
# Out:
# Features by importance:
# [(3.4735157054129386, 'bgr'), (3.4074051597651933, 'su'), (3.1526993230442097, 'hemo'), (3.132253352938951, 'sc'), (3.1309610013169764, 'pcv'), (3.1189514951065354, 'bu'), (2.8806453529659772, 'al'), (2.8576239599341187, 'rc'), (2.7655920925735424, 'sg'), (2.3224361397955797, 'sod'), (1.8878847922335185, 'age'), (1.767263189829048, 'wc'), (1.45471831600133, 'bp'), (0.8870929709467983, 'pot')]
