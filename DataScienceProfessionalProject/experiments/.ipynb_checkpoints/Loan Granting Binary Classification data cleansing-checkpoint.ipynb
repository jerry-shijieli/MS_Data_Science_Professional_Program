# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
datafile = "LoanGrantingCleanedDatasetV6.csv"
raw_data = pd.read_csv(datafile, header=0)

# %%
#raw_data.head(20)

# %%
#raw_data.describe()

# %%
df = pd.DataFrame(raw_data)
# convert Loan Status into discrete numeric values
df["Loan Status"] = df["Loan Status"].replace("Charged Off", '0')
df["Loan Status"] = df["Loan Status"].replace("Fully Paid", '1')
df["Loan Status"] = df["Loan Status"].astype('int')
# convert Term into discrete numeric values
df["Term"] = df["Term"].replace("Short Term", '0')
df["Term"] = df["Term"].replace("Long Term", '1')
df["Term"] = df["Term"].astype('int')
# convert Home Ownership to discrete numeric values
df["Home Ownership"] = df["Home Ownership"].replace("Rent", '0')
df["Home Ownership"] = df["Home Ownership"].replace("Home Mortgage", '1')
df["Home Ownership"] = df["Home Ownership"].replace("HaveMortgage", '1')
df["Home Ownership"] = df["Home Ownership"].replace("Own Home", '2')
df["Home Ownership"] = df["Home Ownership"].astype('int')
# handle missing value in Credit Score
df["Credit Score"] = df["Credit Score"].apply(lambda x: x if x>0 else np.nan)
df = df.dropna()
df.describe()
# Out:
#         Loan Status  Current Loan Amount          Term  Credit Score  \
# count  88910.000000         8.891000e+04  88910.000000  67572.000000
# mean       0.716871         1.433878e+07      0.247194    721.601951
# std        0.450521         3.502996e+07      0.431383     27.427709
# min        0.000000         4.910000e+02      0.000000    585.000000
# 25%        0.000000         8.283000e+03      0.000000    710.000000
# 50%        1.000000         1.435500e+04      0.000000    730.000000
# 75%        1.000000         2.448500e+04      0.000000    741.000000
# max        1.000000         1.000000e+08      1.000000    751.000000
#
#        Years in current job  Home Ownership  Annual Income  Monthly Debt  \
# count          88910.000000    88910.000000   8.891000e+04  88910.000000
# mean               5.617557        0.670228   5.498285e+04    963.102059
# std                3.745309        0.634564   5.952530e+04    637.524064
# min                0.000000        0.000000  -1.000000e+00      0.000000
# 25%                2.000000        0.000000   1.964975e+04    532.220000
# 50%                6.000000        1.000000   5.053600e+04    843.925000
# 75%               10.000000        1.000000   7.722100e+04   1250.527500
# max               10.000000        2.000000   8.713547e+06  22939.120000
#
#        Years of Credit History  Months since last delinquent  \
# count             88910.000000                  88910.000000
# mean                 18.315313                     15.941784
# std                   7.049175                     22.917713
# min                   3.600000                      0.000000
# 25%                  13.500000                      0.000000
# 50%                  17.000000                      0.000000
# 75%                  21.800000                     29.000000
# max                  70.500000                    176.000000
#
#        Number of Open Accounts  Number of Credit Problems  \
# count             88910.000000               88910.000000
# mean                 11.110348                   0.160477
# std                   4.978461                   0.473746
# min                   0.000000                   0.000000
# 25%                   8.000000                   0.000000
# 50%                  10.000000                   0.000000
# 75%                  14.000000                   0.000000
# max                  76.000000                  15.000000
#
#        Current Credit Balance  Maximum Open Credit  Bankruptcies     Tax Liens
# count            8.891000e+04         8.891000e+04  88910.000000  88910.000000
# mean             1.543593e+04         3.596450e+04      0.112428      0.028220
# std              1.965873e+04         4.041760e+05      0.342969      0.257521
# min              0.000000e+00         0.000000e+00      0.000000      0.000000
# 25%              5.949000e+03         1.277500e+04      0.000000      0.000000
# 50%              1.103900e+04         2.178050e+04      0.000000      0.000000
# 75%              1.930100e+04         3.636700e+04      0.000000      0.000000
# max              1.730472e+06         6.998809e+07      7.000000     15.000000

# %%
df.corr()
# Out:
#                               Loan Status  Current Loan Amount      Term  \
# Loan Status                      1.000000             0.256980 -0.176015
# Current Loan Amount              0.256980             1.000000 -0.044178
# Term                            -0.176015            -0.044178  1.000000
# Credit Score                     0.254803             0.072476 -0.484224
# Years in current job             0.017856             0.003735  0.077226
# Home Ownership                   0.044483             0.006229  0.071852
# Annual Income                    0.046377             0.130307  0.052382
# Monthly Debt                    -0.016951            -0.006283  0.147322
# Years of Credit History          0.038440             0.013930  0.034648
# Months since last delinquent     0.004191            -0.001800 -0.006811
# Number of Open Accounts         -0.016650             0.001294  0.076949
# Number of Credit Problems       -0.011768             0.004312 -0.022397
# Current Credit Balance           0.009337             0.003092  0.093694
# Maximum Open Credit              0.010776            -0.003058  0.008095
# Bankruptcies                     0.000303             0.005118 -0.025463
# Tax Liens                       -0.014797             0.001941 -0.002451
#
#                               Credit Score  Years in current job  \
# Loan Status                       0.254803              0.017856
# Current Loan Amount               0.072476              0.003735
# Term                             -0.484224              0.077226
# Credit Score                      1.000000             -0.015694
# Years in current job             -0.015694              1.000000
# Home Ownership                    0.035336              0.139783
# Annual Income                     0.011361              0.076318
# Monthly Debt                     -0.088383              0.147131
# Years of Credit History           0.086508              0.154295
# Months since last delinquent     -0.055479              0.038679
# Number of Open Accounts          -0.031069              0.063931
# Number of Credit Problems        -0.052908              0.018768
# Current Credit Balance           -0.010812              0.098723
# Maximum Open Credit               0.017630              0.001028
# Bankruptcies                     -0.039670              0.018728
# Tax Liens                        -0.022629              0.006047
#
#                               Home Ownership  Annual Income  Monthly Debt  \
# Loan Status                         0.044483       0.046377     -0.016951
# Current Loan Amount                 0.006229       0.130307     -0.006283
# Term                                0.071852       0.052382      0.147322
# Credit Score                        0.035336       0.011361     -0.088383
# Years in current job                0.139783       0.076318      0.147131
# Home Ownership                      1.000000       0.076885      0.127093
# Annual Income                       0.076885       1.000000      0.345310
# Monthly Debt                        0.127093       0.345310      1.000000
# Years of Credit History             0.170081       0.113996      0.191442
# Months since last delinquent        0.012298       0.009310      0.009229
# Number of Open Accounts             0.096414       0.107032      0.408207
# Number of Credit Problems           0.007564      -0.010895     -0.051599
# Current Credit Balance              0.124881       0.220030      0.473146
# Maximum Open Credit                 0.023733       0.026012      0.036382
# Bankruptcies                       -0.000134      -0.035929     -0.078828
# Tax Liens                           0.009319       0.034245      0.024032
#
#                               Years of Credit History  \
# Loan Status                                  0.038440
# Current Loan Amount                          0.013930
# Term                                         0.034648
# Credit Score                                 0.086508
# Years in current job                         0.154295
# Home Ownership                               0.170081
# Annual Income                                0.113996
# Monthly Debt                                 0.191442
# Years of Credit History                      1.000000
# Months since last delinquent                 0.083841
# Number of Open Accounts                      0.127471
# Number of Credit Problems                    0.061496
# Current Credit Balance                       0.204948
# Maximum Open Credit                          0.030892
# Bankruptcies                                 0.064039
# Tax Liens                                    0.020706
#
#                               Months since last delinquent  \
# Loan Status                                       0.004191
# Current Loan Amount                              -0.001800
# Term                                             -0.006811
# Credit Score                                     -0.055479
# Years in current job                              0.038679
# Home Ownership                                    0.012298
# Annual Income                                     0.009310
# Monthly Debt                                      0.009229
# Years of Credit History                           0.083841
# Months since last delinquent                      1.000000
# Number of Open Accounts                           0.031859
# Number of Credit Problems                         0.076821
# Current Credit Balance                           -0.069561
# Maximum Open Credit                              -0.010993
# Bankruptcies                                      0.054803
# Tax Liens                                         0.029166
#
#                               Number of Open Accounts  \
# Loan Status                                 -0.016650
# Current Loan Amount                          0.001294
# Term                                         0.076949
# Credit Score                                -0.031069
# Years in current job                         0.063931
# Home Ownership                               0.096414
# Annual Income                                0.107032
# Monthly Debt                                 0.408207
# Years of Credit History                      0.127471
# Months since last delinquent                 0.031859
# Number of Open Accounts                      1.000000
# Number of Credit Problems                   -0.014123
# Current Credit Balance                       0.224165
# Maximum Open Credit                          0.029982
# Bankruptcies                                -0.025117
# Tax Liens                                    0.007844
#
#                               Number of Credit Problems  \
# Loan Status                                   -0.011768
# Current Loan Amount                            0.004312
# Term                                          -0.022397
# Credit Score                                  -0.052908
# Years in current job                           0.018768
# Home Ownership                                 0.007564
# Annual Income                                 -0.010895
# Monthly Debt                                  -0.051599
# Years of Credit History                        0.061496
# Months since last delinquent                   0.076821
# Number of Open Accounts                       -0.014123
# Number of Credit Problems                      1.000000
# Current Credit Balance                        -0.107929
# Maximum Open Credit                           -0.012098
# Bankruptcies                                   0.750859
# Tax Liens                                      0.589512
#
#                               Current Credit Balance  Maximum Open Credit  \
# Loan Status                                 0.009337             0.010776
# Current Loan Amount                         0.003092            -0.003058
# Term                                        0.093694             0.008095
# Credit Score                               -0.010812             0.017630
# Years in current job                        0.098723             0.001028
# Home Ownership                              0.124881             0.023733
# Annual Income                               0.220030             0.026012
# Monthly Debt                                0.473146             0.036382
# Years of Credit History                     0.204948             0.030892
# Months since last delinquent               -0.069561            -0.010993
# Number of Open Accounts                     0.224165             0.029982
# Number of Credit Problems                  -0.107929            -0.012098
# Current Credit Balance                      1.000000             0.133361
# Maximum Open Credit                         0.133361             1.000000
# Bankruptcies                               -0.119789            -0.014529
# Tax Liens                                  -0.013181            -0.001600
#
#                               Bankruptcies  Tax Liens
# Loan Status                       0.000303  -0.014797
# Current Loan Amount               0.005118   0.001941
# Term                             -0.025463  -0.002451
# Credit Score                     -0.039670  -0.022629
# Years in current job              0.018728   0.006047
# Home Ownership                   -0.000134   0.009319
# Annual Income                    -0.035929   0.034245
# Monthly Debt                     -0.078828   0.024032
# Years of Credit History           0.064039   0.020706
# Months since last delinquent      0.054803   0.029166
# Number of Open Accounts          -0.025117   0.007844
# Number of Credit Problems         0.750859   0.589512
# Current Credit Balance           -0.119789  -0.013181
# Maximum Open Credit              -0.014529  -0.001600
# Bankruptcies                      1.000000   0.046089
# Tax Liens                         0.046089   1.000000

# %%
df.columns.tolist()
# Out:
# ['Loan ID',
#  'Customer ID',
#  'Loan Status',
#  'Current Loan Amount',
#  'Term',
#  'Credit Score',
#  'Years in current job',
#  'Home Ownership',
#  'Annual Income',
#  'Purpose',
#  'Monthly Debt',
#  'Years of Credit History',
#  'Months since last delinquent',
#  'Number of Open Accounts',
#  'Number of Credit Problems',
#  'Current Credit Balance',
#  'Maximum Open Credit',
#  'Bankruptcies',
#  'Tax Liens']

# %%
df.dtypes
# Out:
# Loan ID                          object
# Customer ID                      object
# Loan Status                       int64
# Current Loan Amount               int64
# Term                              int64
# Credit Score                    float64
# Years in current job              int64
# Home Ownership                    int64
# Annual Income                     int64
# Purpose                          object
# Monthly Debt                    float64
# Years of Credit History         float64
# Months since last delinquent      int64
# Number of Open Accounts           int64
# Number of Credit Problems         int64
# Current Credit Balance            int64
# Maximum Open Credit               int64
# Bankruptcies                      int64
# Tax Liens                         int64
# dtype: object

# %%
df.describe()
# Out:
#         Loan Status  Current Loan Amount          Term  Credit Score  \
# count  88910.000000         8.891000e+04  88910.000000  67572.000000
# mean       0.716871         1.433878e+07      0.247194    721.601951
# std        0.450521         3.502996e+07      0.431383     27.427709
# min        0.000000         4.910000e+02      0.000000    585.000000
# 25%        0.000000         8.283000e+03      0.000000    710.000000
# 50%        1.000000         1.435500e+04      0.000000    730.000000
# 75%        1.000000         2.448500e+04      0.000000    741.000000
# max        1.000000         1.000000e+08      1.000000    751.000000
#
#        Years in current job  Home Ownership  Annual Income  Monthly Debt  \
# count          88910.000000    88910.000000   8.891000e+04  88910.000000
# mean               5.617557        0.670228   5.498285e+04    963.102059
# std                3.745309        0.634564   5.952530e+04    637.524064
# min                0.000000        0.000000  -1.000000e+00      0.000000
# 25%                2.000000        0.000000   1.964975e+04    532.220000
# 50%                6.000000        1.000000   5.053600e+04    843.925000
# 75%               10.000000        1.000000   7.722100e+04   1250.527500
# max               10.000000        2.000000   8.713547e+06  22939.120000
#
#        Years of Credit History  Months since last delinquent  \
# count             88910.000000                  88910.000000
# mean                 18.315313                     15.941784
# std                   7.049175                     22.917713
# min                   3.600000                      0.000000
# 25%                  13.500000                      0.000000
# 50%                  17.000000                      0.000000
# 75%                  21.800000                     29.000000
# max                  70.500000                    176.000000
#
#        Number of Open Accounts  Number of Credit Problems  \
# count             88910.000000               88910.000000
# mean                 11.110348                   0.160477
# std                   4.978461                   0.473746
# min                   0.000000                   0.000000
# 25%                   8.000000                   0.000000
# 50%                  10.000000                   0.000000
# 75%                  14.000000                   0.000000
# max                  76.000000                  15.000000
#
#        Current Credit Balance  Maximum Open Credit  Bankruptcies     Tax Liens
# count            8.891000e+04         8.891000e+04  88910.000000  88910.000000
# mean             1.543593e+04         3.596450e+04      0.112428      0.028220
# std              1.965873e+04         4.041760e+05      0.342969      0.257521
# min              0.000000e+00         0.000000e+00      0.000000      0.000000
# 25%              5.949000e+03         1.277500e+04      0.000000      0.000000
# 50%              1.103900e+04         2.178050e+04      0.000000      0.000000
# 75%              1.930100e+04         3.636700e+04      0.000000      0.000000
# max              1.730472e+06         6.998809e+07      7.000000     15.000000

# %%
df["Purpose"].unique()
# Out:
# array(['Debt Consolidation', 'Home Improvements', 'other', 'Business Loan',
#        'small_business', 'Other', 'moving', 'Buy a Car', 'Medical Bills',
#        'Buy House', 'Take a Trip', 'vacation', 'major_purchase',
#        'Educational Expenses', 'wedding', 'renewable_energy'], dtype=object)

# %%
df["Purpose"].value_counts().plot(kind='bar')

# %%
# conditional histogram
g_df = df.groupby(["Loan Status"])
fig = plt.figure(figsize=(12, 12))
fig.clf()
ax = fig.gca()
df["Loan Status"].hist(by=df["Purpose"], ax=ax)
# Out:
# /Users/Jerry/anaconda/lib/python2.7/site-packages/pandas/tools/plotting.py:3003: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   ylabelsize=ylabelsize, yrot=yrot, **kwds)
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x115587490>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1161ae610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1163e6150>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x116542610>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1165a4790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1167d4750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x116838450>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1168b8710>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x116bd05d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x116c3d4d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x116cbe6d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x116e995d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x116f1ca90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x116ec7f90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11700b650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11708f850>]], dtype=object)

# %%
# convert Purpose into discrete numeric values
df["Purpose"] = df["Purpose"].replace("Debt Consolidation", '1')
df["Purpose"] = df["Purpose"].replace("Buy a Car", '1')
df["Purpose"] = df["Purpose"].replace("Buy House", '1')
df["Purpose"] = df["Purpose"].replace("Other", '1')
df["Purpose"] = df["Purpose"].replace("Medical Bills", '1')
df["Purpose"] = df["Purpose"].replace("Home Improvements", '1')
df["Purpose"] = df["Purpose"].replace("Educational Expenses", '1')
df["Purpose"] = df["Purpose"].replace("other", '1')
df["Purpose"] = df["Purpose"].replace("Take a Trip", '1')
df["Purpose"] = df["Purpose"].replace("major_purchase", '1')
df["Purpose"] = df["Purpose"].replace("wedding", '1')
df["Purpose"] = df["Purpose"].replace("vacation", '1')
df["Purpose"] = df["Purpose"].replace("[^0-9]", '0', regex=True)
df["Purpose"] = df["Purpose"].astype(int)
df["Purpose"].unique()
# Out:
# array([1, 0])

# %%
## Create pair-wise scatter plots         
def auto_pairs(plot_cols, df):
    import matplotlib.pyplot as plt
    from pandas.tools.plotting import scatter_matrix
    fig = plt.figure(figsize=(36, 36))
    fig.clf()
    ax = fig.gca()
    scatter_matrix(df[plot_cols], alpha=0.3, 
               diagonal='kde', ax = ax)
    return 'Done' 

## Numeric columns
plot_cols = df.columns.tolist()#.remove("Purpose")

auto_pairs(plot_cols, df)

# %%
## Function to plot conditioned histograms
def cond_hists(df, plot_cols, grid_col):
    import matplotlib.pyplot as plt
    import seaborn as sns
    ## Loop over the list of columns
    for col in plot_cols:
        grid1 = sns.FacetGrid(df, col=grid_col)
        grid1.map(plt.hist, col, alpha=.7)
    return grid_col

## Define columns for making a conditioned histogram
plot_cols2 = df.columns.tolist()
plot_cols2.remove("Loan Status")
plot_cols2.remove("Loan ID")
plot_cols2.remove("Customer ID")

cond_hists(df, plot_cols2, 'Loan Status')

# %%
df.corr()

# %%
## Plot categorical variables as box plots
def income_boxplot(df):
    import numpy as np
    import matplotlib.pyplot as plt
    
    cols = df.columns.tolist()
    for col in cols:
        if(df[col].dtype in [np.int64, np.int32, np.float64]):                  
            fig = plt.figure(figsize = (5,5))
            fig.clf()
            ax = fig.gca() 
            df.boxplot(column = [col], ax = ax, by = ['Loan Status'])          
    return('Done') 

income_boxplot(df)

# %%
df.describe()

# %%
df.boxplot(column="Current Loan Amount")
